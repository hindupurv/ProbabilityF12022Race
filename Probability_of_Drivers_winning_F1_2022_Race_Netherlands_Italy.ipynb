# %% [markdown]
# F1!
#
# Question 1: The season is over and Max Verstappen won, again! But let's assume the season is not over and there are still two F1 races coming up: The Netherlands Grand Prix coming up this weekend and the Italian Grand Prix the weekend after.  Given these standings (please do not use team standings given on the same Web site, use driver standings), what is the Probability Distribution for each F1 driver to win the Netherlands Grand Prix? What is the Probability Distribution for each F1 driver to win both the Netherlands and Italian Grand Prix? What is the probability for Red Bull to win both races? What is the probability for Red Bull to win at least one race? Note that Red Bull, and each other racing team, has two drivers per race.
#
# Question 2: If Red Bull wins the first race, what is the probability that Red Bull wins the next one? If Red Bull wins at least one of these two races, what is the probability Red Bull wins both races? How about Ferrari, Mercedes, and Alpine-Renault?
#
# Question 3: Red Bull wins one of these two races on a rainy day. What is the probability Red Bull wins both races, assuming races can be held on either rainy, sunny, cloudy, snowy or foggy days? Assume that rain, sun, clouds, snow, and fog are the only possible weather conditions on race tracks and there is an equal probability for each one of these weather events.
#
# Question 4: After the races, there is always a media blitz! Knowing that everyone has a favorite F1 driver, fashion brands pay F1 drivers to be their ambassadors. Let's assume that brands combine to organize one hundred fashion shows every season and that each retired or active F1 driver is under contract to attend exactly one fashion show every season in order to wear a fashion brand's clothes and to represent the brand (e.g. Gucci). For the sake of simplicity let's also assume that there are exactly 100 F1 retired and active driveres. If you go to a fashion show, what is the probability you will see your favorite driver (e.g. Lewis Hamilton)? What is the probability you will see a Formula 1 driver? How many fashion shows do you need to attend per season to have at least a 50% chance to share a cocktail with a Formula 1 driver?

# %%
from fractions import Fraction
class ProbDist(dict):
    """A Probability Distribution; an {outcome: probability} mapping."""
    def __init__(self, mapping=(), **kwargs):
        self.update(mapping, **kwargs)
        # Make probabilities sum to 1.0; assert no negative probabilities
        total = sum(self.values())
        for outcome in self:
            self[outcome] = self[outcome] / total
            assert self[outcome] >= 0

# %%
def p(event, space): 
    """The probability of an event, given a sample space of equiprobable outcomes. 
    event: a collection of outcomes, or a predicate that is true of outcomes in the event. 
    space: a set of outcomes or a probability distribution of {outcome: frequency} pairs."""
    # branch on the type of the first argument
    if is_predicate(event):
        # transform the mapping (untangible) 'event' into the collection (tangible) 'event'
        event = such_that(event, space)
        
    if isinstance(space, ProbDist):
        # if space is a dictionary of distinct probabilities, where each item does not count as the same amount
        return sum(space[k] for k in space if k in event)
    else:
        # space is not a dictionary but a collection, let's fall back to our original division
        return Fraction(len(event & space), len(space))

is_predicate = callable

def such_that(predicate, space): 
    """The outcomes in the sample pace for which the predicate is true.
    If space is a set, return a subset {outcome,...} with outcomes where predicate(element) is true;
    if space is a ProbDist, return a ProbDist {outcome: frequency,...} with outcomes where predicate(element) is true."""
    if isinstance(space, ProbDist):
        # print(ProbDist({o:space[o] for o in space if predicate(o)}))
        return ProbDist({o:space[o] for o in space if predicate(o)})
    else:
        return {o for o in space if predicate(o)}

# %% [markdown]
# ANSWER 1 :
#
#     Probability Distribution for each player to win the Netherlands Grand Prix :

# %%
NGP = ProbDist(
     MV = 341,
    CL = 237,
    SP = 235,
    GR = 203,
    CS = 202,
    LH = 170,
    LN = 100,
    EO = 66,
    FA = 59,
    VB = 46,
    DR = 29,
    SV = 24,
    PG = 23,
    KM = 22,
    LS = 13,
    MS = 12,
    YT = 11,
    ZG = 6,
    AA = 4,
    NV = 2,
    NL = 0,
    NH = 0)
NGP
# Out:
# {'MV': 0.1889196675900277,
#  'CL': 0.13130193905817175,
#  'SP': 0.13019390581717452,
#  'GR': 0.11246537396121883,
#  'CS': 0.11191135734072022,
#  'LH': 0.09418282548476455,
#  'LN': 0.055401662049861494,
#  'EO': 0.03656509695290859,
#  'FA': 0.032686980609418284,
#  'VB': 0.02548476454293629,
#  'DR': 0.016066481994459834,
#  'SV': 0.013296398891966758,
#  'PG': 0.012742382271468145,
#  'KM': 0.01218836565096953,
#  'LS': 0.007202216066481994,
#  'MS': 0.006648199445983379,
#  'YT': 0.006094182825484765,
#  'ZG': 0.0033240997229916896,
#  'AA': 0.00221606648199446,
#  'NV': 0.00110803324099723,
#  'NL': 0.0,
#  'NH': 0.0}

# %% [markdown]
#     Assuming Probability Distribution for Italian Grand Prix (IGP) is same as for Netherlands Grand Prix (NGP)

# %%
IGP = NGP

# %% [markdown]
#     Probability Distribution for the 2 races :

# %%
NGPIGP = ProbDist({a + b : NGP[a] * IGP[b] for a in NGP for b in IGP })
NGPIGP
# Out:
# {'MVMV': 0.03569064080232656,
#  'MVCL': 0.024805518680795884,
#  'MVSP': 0.024596189409227986,
#  'MVGR': 0.02124692106414162,
#  'MVCS': 0.02114225642835767,
#  'MVLH': 0.01779298808327131,
#  'MVLN': 0.010466463578394886,
#  'MVEO': 0.0069078659617406255,
#  'MVFA': 0.006175213511252983,
#  'MVVB': 0.004814573246061648,
#  'MVDR': 0.003035274437734517,
#  'MVSV': 0.0025119512588147727,
#  'MVPG': 0.002407286623030824,
#  'MVKM': 0.0023026219872468753,
#  'MVLS': 0.0013606402651913352,
#  'MVMS': 0.0012559756294073863,
#  'MVYT': 0.0011513109936234377,
#  'MVZG': 0.0006279878147036932,
#  'MVAA': 0.0004186585431357955,
#  'MVNV': 0.00020932927156789774,
#  'MVNL': 0.0,
#  'MVNH': 0.0,
#  'CLMV': 0.024805518680795884,
#  'CLCL': 0.01724019920043585,
#  'CLSP': 0.017094712287352,
#  'CLGR': 0.014766921678010452,
#  'CLCS': 0.014694178221468528,
#  'CLLH': 0.01236638761212698,
#  'CLLN': 0.007274345654192341,
#  'CLEO': 0.004801068131766946,
#  'CLFA': 0.004291863935973481,
#  'CLVB': 0.003346199000928477,
#  'CLDR': 0.002109560239715779,
#  'CLSV': 0.0017458429570061617,
#  'CLPG': 0.0016730995004642386,
#  'CLKM': 0.001600356043922315,
#  'CLLS': 0.0009456649350450043,
#  'CLMS': 0.0008729214785030808,
#  'CLYT': 0.0008001780219611575,
#  'CLZG': 0.0004364607392515404,
#  'CLAA': 0.00029097382616769365,
#  'CLNV': 0.00014548691308384682,
#  'CLNL': 0.0,
#  'CLNH': 0.0,
#  'SPMV': 0.024596189409227986,
#  'SPCL': 0.017094712287352,
#  'SPSP': 0.01695045311193131,
#  'SPGR': 0.014642306305200237,
#  'SPCS': 0.014570176717489891,
#  'SPLH': 0.01226202991075882,
#  'SPLN': 0.007212958771034599,
#  'SPEO': 0.004760552788882836,
#  'SPFA': 0.004255645674910414,
#  'SPVB': 0.003317961034675916,
#  'SPDR': 0.0020917580436000337,
#  'SPSV': 0.0017311101050483037,
#  'SPPG': 0.001658980517337958,
#  'SPKM': 0.001586850929627612,
#  'SPLS': 0.000937684640234498,
#  'SPMS': 0.0008655550525241519,
#  'SPYT': 0.000793425464813806,
#  'SPZG': 0.00043277752626207593,
#  'SPAA': 0.000288518350841384,
#  'SPNV': 0.000144259175420692,
#  'SPNL': 0.0,
#  'SPNH': 0.0,
#  'GRMV': 0.02124692106414162,
#  'GRCL': 0.014766921678010452,
#  'GRSP': 0.014642306305200237,
#  'GRGR': 0.012648460340236799,
#  'GRCS': 0.012586152653831692,
#  'GRLH': 0.010592306688868257,
#  'GRLN': 0.0062307686405107384,
#  'GREO': 0.004112307302737088,
#  'GRFA': 0.003676153497901336,
#  'GRVB': 0.00286615357463494,
#  'GRDR': 0.0018069229057481144,
#  'GRSV': 0.0014953844737225772,
#  'GRPG': 0.00143307678731747,
#  'GRKM': 0.0013707691009123626,
#  'GRLS': 0.000809999923266396,
#  'GRMS': 0.0007476922368612886,
#  'GRYT': 0.0006853845504561813,
#  'GRZG': 0.0003738461184306443,
#  'GRAA': 0.00024923074562042957,
#  'GRNV': 0.00012461537281021479,
#  'GRNL': 0.0,
#  'GRNH': 0.0,
#  'CSMV': 0.02114225642835767,
#  'CSCL': 0.014694178221468528,
#  'CSSP': 0.014570176717489891,
#  'CSGR': 0.012586152653831692,
#  'CSCS': 0.012524151901842374,
#  'CSLH': 0.010540127838184176,
#  'CSLN': 0.006200075198931868,
#  'CSEO': 0.004092049631295033,
#  'CSFA': 0.003658044367369802,
#  'CSVB': 0.0028520345915086596,
#  'CSDR': 0.0017980218076902419,
#  'CSSV': 0.0014880180477436483,
#  'CSPG': 0.0014260172957543298,
#  'CSKM': 0.0013640165437650111,
#  'CSLS': 0.0008060097758611428,
#  'CSMS': 0.0007440090238718241,
#  'CSYT': 0.0006820082718825056,
#  'CSZG': 0.00037200451193591206,
#  'CSAA': 0.00024800300795727476,
#  'CSNV': 0.00012400150397863738,
#  'CSNL': 0.0,
#  'CSNH': 0.0,
#  'LHMV': 0.01779298808327131,
#  'LHCL': 0.01236638761212698,
#  'LHSP': 0.01226202991075882,
#  'LHGR': 0.010592306688868257,
#  'LHCS': 0.010540127838184176,
#  'LHLH': 0.008870404616293614,
#  'LHLN': 0.005217885068408008,
#  'LHEO': 0.0034438041451492858,
#  'LHFA': 0.003078552190360725,
#  'LHVB': 0.002400227131467684,
#  'LHDR': 0.0015131866698383223,
#  'LHSV': 0.001252292416417922,
#  'LHPG': 0.001200113565733842,
#  'LHKM': 0.0011479347150497618,
#  'LHLS': 0.0006783250588930411,
#  'LHMS': 0.000626146208208961,
#  'LHYT': 0.0005739673575248809,
#  'LHZG': 0.0003130731041044805,
#  'LHAA': 0.00020871540273632034,
#  'LHNV': 0.00010435770136816017,
#  'LHNL': 0.0,
#  'LHNH': 0.0,
#  'LNMV': 0.010466463578394886,
#  'LNCL': 0.007274345654192341,
#  'LNSP': 0.007212958771034599,
#  'LNGR': 0.0062307686405107384,
#  'LNCS': 0.006200075198931868,
#  'LNLH': 0.005217885068408008,
#  'LNLN': 0.003069344157887063,
#  'LNEO': 0.002025767144205462,
#  'LNFA': 0.0018109130531533675,
#  'LNVB': 0.0014118983126280493,
#  'LNDR': 0.0008901098057872484,
#  'LNSV': 0.0007366425978928952,
#  'LNPG': 0.0007059491563140246,
#  'LNKM': 0.000675255714735154,
#  'LNLS': 0.00039901474052531826,
#  'LNMS': 0.0003683212989464476,
#  'LNYT': 0.000337627857367577,
#  'LNZG': 0.0001841606494732238,
#  'LNAA': 0.00012277376631548254,
#  'LNNV': 6.138688315774127e-05,
#  'LNNL': 0.0,
#  'LNNH': 0.0,
#  'EOMV': 0.0069078659617406255,
#  'EOCL': 0.004801068131766946,
#  'EOSP': 0.004760552788882836,
#  'EOGR': 0.004112307302737088,
#  'EOCS': 0.004092049631295033,
#  'EOLH': 0.0034438041451492858,
#  'EOLN': 0.002025767144205462,
#  'EOEO': 0.0013370063151756052,
#  'EOFA': 0.0011952026150812227,
#  'EOVB': 0.0009318528863345127,
#  'EODR': 0.0005874724718195841,
#  'EOSV': 0.0004861841146093109,
#  'EOPG': 0.00046592644316725633,
#  'EOKM': 0.0004456687717252017,
#  'EOLS': 0.0002633497287467101,
#  'EOMS': 0.00024309205730465544,
#  'EOYT': 0.00022283438586260084,
#  'EOZG': 0.00012154602865232772,
#  'EOAA': 8.103068576821849e-05,
#  'EONV': 4.051534288410924e-05,
#  'EONL': 0.0,
#  'EONH': 0.0,
#  'FAMV': 0.006175213511252983,
#  'FACL': 0.004291863935973481,
#  'FASP': 0.004255645674910414,
#  'FAGR': 0.003676153497901336,
#  'FACS': 0.003658044367369802,
#  'FALH': 0.003078552190360725,
#  'FALN': 0.0018109130531533675,
#  'FAEO': 0.0011952026150812227,
#  'FAFA': 0.001068438701360487,
#  'FAVB': 0.0008330200044505492,
#  'FADR': 0.0005251647854144766,
#  'FASV': 0.00043461913275680817,
#  'FAPG': 0.0004165100022252746,
#  'FAKM': 0.0003984008716937409,
#  'FALS': 0.0002354186969099378,
#  'FAMS': 0.00021730956637840409,
#  'FAYT': 0.00019920043584687044,
#  'FAZG': 0.00010865478318920204,
#  'FAAA': 7.243652212613471e-05,
#  'FANV': 3.6218261063067354e-05,
#  'FANL': 0.0,
#  'FANH': 0.0,
#  'VBMV': 0.004814573246061648,
#  'VBCL': 0.003346199000928477,
#  'VBSP': 0.003317961034675916,
#  'VBGR': 0.00286615357463494,
#  'VBCS': 0.0028520345915086596,
#  'VBLH': 0.002400227131467684,
#  'VBLN': 0.0014118983126280493,
#  'VBEO': 0.0009318528863345127,
#  'VBFA': 0.0008330200044505492,
#  'VBVB': 0.0006494732238089027,
#  'VBDR': 0.00040945051066213433,
#  'VBSV': 0.0003388555950307318,
#  'VBPG': 0.0003247366119044514,
#  'VBKM': 0.00031061762877817087,
#  'VBLS': 0.0001835467806416464,
#  'VBMS': 0.0001694277975153659,
#  'VBYT': 0.00015530881438908544,
#  'VBZG': 8.471389875768296e-05,
#  'VBAA': 5.647593250512198e-05,
#  'VBNV': 2.823796625256099e-05,
#  'VBNL': 0.0,
#  'VBNH': 0.0,
#  'DRMV': 0.003035274437734517,
#  'DRCL': 0.002109560239715779,
#  'DRSP': 0.0020917580436000337,
#  'DRGR': 0.0018069229057481144,
#  'DRCS': 0.0017980218076902419,
#  'DRLH': 0.0015131866698383223,
#  'DRLN': 0.0008901098057872484,
#  'DREO': 0.0005874724718195841,
#  'DRFA': 0.0005251647854144766,
#  'DRVB': 0.00040945051066213433,
#  'DRDR': 0.00025813184367830206,
#  'DRSV': 0.00021362635338893963,
#  'DRPG': 0.00020472525533106716,
#  'DRKM': 0.00019582415727319467,
#  'DRLS': 0.0001157142747523423,
#  'DRMS': 0.00010681317669446981,
#  'DRYT': 9.791207863659734e-05,
#  'DRZG': 5.340658834723491e-05,
#  'DRAA': 3.560439223148994e-05,
#  'DRNV': 1.780219611574497e-05,
#  'DRNL': 0.0,
#  'DRNH': 0.0,
#  'SVMV': 0.0025119512588147727,
#  'SVCL': 0.0017458429570061617,
#  'SVSP': 0.0017311101050483037,
#  'SVGR': 0.0014953844737225772,
#  'SVCS': 0.0014880180477436483,
#  'SVLH': 0.001252292416417922,
#  'SVLN': 0.0007366425978928952,
#  'SVEO': 0.0004861841146093109,
#  'SVFA': 0.00043461913275680817,
#  'SVVB': 0.0003388555950307318,
#  'SVDR': 0.00021362635338893963,
#  'SVSV': 0.00017679422349429485,
#  'SVPG': 0.0001694277975153659,
#  'SVKM': 0.00016206137153643694,
#  'SVLS': 9.576353772607638e-05,
#  'SVMS': 8.839711174714742e-05,
#  'SVYT': 8.103068576821847e-05,
#  'SVZG': 4.419855587357371e-05,
#  'SVAA': 2.946570391571581e-05,
#  'SVNV': 1.4732851957857905e-05,
#  'SVNL': 0.0,
#  'SVNH': 0.0,
#  'PGMV': 0.002407286623030824,
#  'PGCL': 0.0016730995004642386,
#  'PGSP': 0.001658980517337958,
#  'PGGR': 0.00143307678731747,
#  'PGCS': 0.0014260172957543298,
#  'PGLH': 0.001200113565733842,
#  'PGLN': 0.0007059491563140246,
#  'PGEO': 0.00046592644316725633,
#  'PGFA': 0.0004165100022252746,
#  'PGVB': 0.0003247366119044514,
#  'PGDR': 0.00020472525533106716,
#  'PGSV': 0.0001694277975153659,
#  'PGPG': 0.0001623683059522257,
#  'PGKM': 0.00015530881438908544,
#  'PGLS': 9.17733903208232e-05,
#  'PGMS': 8.471389875768296e-05,
#  'PGYT': 7.765440719454272e-05,
#  'PGZG': 4.235694937884148e-05,
#  'PGAA': 2.823796625256099e-05,
#  'PGNV': 1.4118983126280495e-05,
#  'PGNL': 0.0,
#  'PGNH': 0.0,
#  'KMMV': 0.0023026219872468753,
#  'KMCL': 0.001600356043922315,
#  'KMSP': 0.001586850929627612,
#  'KMGR': 0.0013707691009123626,
#  'KMCS': 0.0013640165437650111,
#  'KMLH': 0.0011479347150497618,
#  'KMLN': 0.000675255714735154,
#  'KMEO': 0.0004456687717252017,
#  'KMFA': 0.0003984008716937409,
#  'KMVB': 0.00031061762877817087,
#  'KMDR': 0.00019582415727319467,
#  'KMSV': 0.00016206137153643694,
#  'KMPG': 0.00015530881438908544,
#  'KMKM': 0.00014855625724173387,
#  'KMLS': 8.778324291557002e-05,
#  'KMMS': 8.103068576821847e-05,
#  'KMYT': 7.427812862086694e-05,
#  'KMZG': 4.0515342884109236e-05,
#  'KMAA': 2.7010228589406163e-05,
#  'KMNV': 1.3505114294703081e-05,
#  'KMNL': 0.0,
#  'KMNH': 0.0,
#  'LSMV': 0.0013606402651913352,
#  'LSCL': 0.0009456649350450043,
#  'LSSP': 0.000937684640234498,
#  'LSGR': 0.000809999923266396,
#  'LSCS': 0.0008060097758611428,
#  'LSLH': 0.0006783250588930411,
#  'LSLN': 0.00039901474052531826,
#  'LSEO': 0.0002633497287467101,
#  'LSFA': 0.0002354186969099378,
#  'LSVB': 0.0001835467806416464,
#  'LSDR': 0.0001157142747523423,
#  'LSSV': 9.576353772607638e-05,
#  'LSPG': 9.17733903208232e-05,
#  'LSKM': 8.778324291557002e-05,
#  'LSLS': 5.1871916268291375e-05,
#  'LSMS': 4.788176886303819e-05,
#  'LSYT': 4.389162145778501e-05,
#  'LSZG': 2.3940884431519095e-05,
#  'LSAA': 1.596058962101273e-05,
#  'LSNV': 7.980294810506365e-06,
#  'LSNL': 0.0,
#  'LSNH': 0.0,
#  'MSMV': 0.0012559756294073863,
#  'MSCL': 0.0008729214785030808,
#  'MSSP': 0.0008655550525241519,
#  'MSGR': 0.0007476922368612886,
#  'MSCS': 0.0007440090238718241,
#  'MSLH': 0.000626146208208961,
#  'MSLN': 0.0003683212989464476,
#  'MSEO': 0.00024309205730465544,
#  'MSFA': 0.00021730956637840409,
#  'MSVB': 0.0001694277975153659,
#  'MSDR': 0.00010681317669446981,
#  'MSSV': 8.839711174714742e-05,
#  'MSPG': 8.471389875768296e-05,
#  'MSKM': 8.103068576821847e-05,
#  'MSLS': 4.788176886303819e-05,
#  'MSMS': 4.419855587357371e-05,
#  'MSYT': 4.0515342884109236e-05,
#  'MSZG': 2.2099277936786856e-05,
#  'MSAA': 1.4732851957857905e-05,
#  'MSNV': 7.366425978928952e-06,
#  'MSNL': 0.0,
#  'MSNH': 0.0,
#  'YTMV': 0.0011513109936234377,
#  'YTCL': 0.0008001780219611575,
#  'YTSP': 0.000793425464813806,
#  'YTGR': 0.0006853845504561813,
#  'YTCS': 0.0006820082718825056,
#  'YTLH': 0.0005739673575248809,
#  'YTLN': 0.000337627857367577,
#  'YTEO': 0.00022283438586260084,
#  'YTFA': 0.00019920043584687044,
#  'YTVB': 0.00015530881438908544,
#  'YTDR': 9.791207863659734e-05,
#  'YTSV': 8.103068576821847e-05,
#  'YTPG': 7.765440719454272e-05,
#  'YTKM': 7.427812862086694e-05,
#  'YTLS': 4.389162145778501e-05,
#  'YTMS': 4.0515342884109236e-05,
#  'YTYT': 3.713906431043347e-05,
#  'YTZG': 2.0257671442054618e-05,
#  'YTAA': 1.3505114294703081e-05,
#  'YTNV': 6.752557147351541e-06,
#  'YTNL': 0.0,
#  'YTNH': 0.0,
#  'ZGMV': 0.0006279878147036932,
#  'ZGCL': 0.0004364607392515404,
#  'ZGSP': 0.00043277752626207593,
#  'ZGGR': 0.0003738461184306443,
#  'ZGCS': 0.00037200451193591206,
#  'ZGLH': 0.0003130731041044805,
#  'ZGLN': 0.0001841606494732238,
#  'ZGEO': 0.00012154602865232772,
#  'ZGFA': 0.00010865478318920204,
#  'ZGVB': 8.471389875768296e-05,
#  'ZGDR': 5.340658834723491e-05,
#  'ZGSV': 4.419855587357371e-05,
#  'ZGPG': 4.235694937884148e-05,
#  'ZGKM': 4.0515342884109236e-05,
#  'ZGLS': 2.3940884431519095e-05,
#  'ZGMS': 2.2099277936786856e-05,
#  'ZGYT': 2.0257671442054618e-05,
#  'ZGZG': 1.1049638968393428e-05,
#  'ZGAA': 7.366425978928952e-06,
#  'ZGNV': 3.683212989464476e-06,
#  'ZGNL': 0.0,
#  'ZGNH': 0.0,
#  'AAMV': 0.0004186585431357955,
#  'AACL': 0.00029097382616769365,
#  'AASP': 0.000288518350841384,
#  'AAGR': 0.00024923074562042957,
#  'AACS': 0.00024800300795727476,
#  'AALH': 0.00020871540273632034,
#  'AALN': 0.00012277376631548254,
#  'AAEO': 8.103068576821849e-05,
#  'AAFA': 7.243652212613471e-05,
#  'AAVB': 5.647593250512198e-05,
#  'AADR': 3.560439223148994e-05,
#  'AASV': 2.946570391571581e-05,
#  'AAPG': 2.823796625256099e-05,
#  'AAKM': 2.7010228589406163e-05,
#  'AALS': 1.596058962101273e-05,
#  'AAMS': 1.4732851957857905e-05,
#  'AAYT': 1.3505114294703081e-05,
#  'AAZG': 7.366425978928952e-06,
#  'AAAA': 4.910950652619302e-06,
#  'AANV': 2.455475326309651e-06,
#  'AANL': 0.0,
#  'AANH': 0.0,
#  'NVMV': 0.00020932927156789774,
#  'NVCL': 0.00014548691308384682,
#  'NVSP': 0.000144259175420692,
#  'NVGR': 0.00012461537281021479,
#  'NVCS': 0.00012400150397863738,
#  'NVLH': 0.00010435770136816017,
#  'NVLN': 6.138688315774127e-05,
#  'NVEO': 4.051534288410924e-05,
#  'NVFA': 3.6218261063067354e-05,
#  'NVVB': 2.823796625256099e-05,
#  'NVDR': 1.780219611574497e-05,
#  'NVSV': 1.4732851957857905e-05,
#  'NVPG': 1.4118983126280495e-05,
#  'NVKM': 1.3505114294703081e-05,
#  'NVLS': 7.980294810506365e-06,
#  'NVMS': 7.366425978928952e-06,
#  'NVYT': 6.752557147351541e-06,
#  'NVZG': 3.683212989464476e-06,
#  'NVAA': 2.455475326309651e-06,
#  'NVNV': 1.2277376631548256e-06,
#  'NVNL': 0.0,
#  'NVNH': 0.0,
#  'NLMV': 0.0,
#  'NLCL': 0.0,
#  'NLSP': 0.0,
#  'NLGR': 0.0,
#  'NLCS': 0.0,
#  'NLLH': 0.0,
#  'NLLN': 0.0,
#  'NLEO': 0.0,
#  'NLFA': 0.0,
#  'NLVB': 0.0,
#  'NLDR': 0.0,
#  'NLSV': 0.0,
#  'NLPG': 0.0,
#  'NLKM': 0.0,
#  'NLLS': 0.0,
#  'NLMS': 0.0,
#  'NLYT': 0.0,
#  'NLZG': 0.0,
#  'NLAA': 0.0,
#  'NLNV': 0.0,
#  'NLNL': 0.0,
#  'NLNH': 0.0,
#  'NHMV': 0.0,
#  'NHCL': 0.0,
#  'NHSP': 0.0,
#  'NHGR': 0.0,
#  'NHCS': 0.0,
#  'NHLH': 0.0,
#  'NHLN': 0.0,
#  'NHEO': 0.0,
#  'NHFA': 0.0,
#  'NHVB': 0.0,
#  'NHDR': 0.0,
#  'NHSV': 0.0,
#  'NHPG': 0.0,
#  'NHKM': 0.0,
#  'NHLS': 0.0,
#  'NHMS': 0.0,
#  'NHYT': 0.0,
#  'NHZG': 0.0,
#  'NHAA': 0.0,
#  'NHNV': 0.0,
#  'NHNL': 0.0,
#  'NHNH': 0.0}

# %% [markdown]
# Probability Distribution for each player to win both the matches (WW):

# %%
WW = ProbDist({o:NGPIGP[o] for o in NGPIGP if o[0] + o[1] == o[2] + o[3]})
WW
# Out:
# {'MVMV': 0.3216972232135693,
#  'CLCL': 0.1553943578975325,
#  'SPSP': 0.15278273451354363,
#  'GRGR': 0.1140067669817767,
#  'CSCS': 0.11288631415284081,
#  'LHLH': 0.07995330063271001,
#  'LNLN': 0.027665501949034603,
#  'EOEO': 0.012051092648999477,
#  'FAFA': 0.009630361228458948,
#  'VBVB': 0.005854020212415724,
#  'DRDR': 0.0023266687139138105,
#  'SVSV': 0.0015935329122643933,
#  'PGPG': 0.001463505053103931,
#  'KMKM': 0.0013390102943332748,
#  'LSLS': 0.00046754698293868487,
#  'MSMS': 0.0003983832280660983,
#  'YTYT': 0.0003347525735833187,
#  'ZGZG': 9.959580701652458e-05,
#  'AAAA': 4.4264803118455374e-05,
#  'NVNV': 1.1066200779613844e-05,
#  'NLNL': 0.0,
#  'NHNH': 0.0}

# %% [markdown]
#     Since there are 2 players in each team, the probability of RedBull winning one race is the probability of MV winning + probability of SP winning.

# %%
def RedBullWins(outcome) : return outcome == 'MV' or outcome == 'SP'

# %% [markdown]
#     Probability of RedBull winning both races : RedBullWins first race and RedBullWins second race.

# %%
RedBullWinsBothRaces = p(RedBullWins, NGP)*p(RedBullWins, IGP)
RedBullWinsBothRaces
# Out:
# 0.10183347273271386

# %% [markdown]
#     Probability of RedBull not winning a race = 1 - Probability of RedBull winning the race
#     For RedBull to win at least one of the races, we can find the probability of 1 - RedBull winning none of the races.

# %%
RedBullWinsAtLeastOne = 1 - (1 - p(RedBullWins, NGP))**2
RedBullWinsAtLeastOne
# Out:
# 0.5363936740816906

# %% [markdown]
# ANSWER 2 :

# %% [markdown]
#     RedBull wins first race, probability that RedBull wins the second race.
#     The sample space will be the cases when RedBull wins the first race, and the event is the cases where redbull wins both the races. So the probability will be = probability of redbull winning both the races / probability of redbull winning the first race.

# %%
RedBullWinsSecondGivenFirst = RedBullWinsBothRaces / p(RedBullWins, NGP)
RedBullWinsSecondGivenFirst
# Out:
# 0.31911357340720226

# %% [markdown]
#     If Red Bull wins at least one of these two races, what is the probability Red Bull wins both races.

# %%
RedBullWinsBothGivenAtLeastOne = RedBullWinsBothRaces / RedBullWinsAtLeastOne
RedBullWinsBothGivenAtLeastOne
# Out:
# 0.18984838497033624

# %% [markdown]
# Now, using the predicates to solve the above question :

# %%
def RedBullWinsFirst(outcome) : return outcome[:2] == 'MV' or outcome[:2] == 'SP'
def RedBullWinsSecond(outcome) : return outcome[2:] == 'MV' or outcome[2:] == 'SP'
RedBullWinsSecondGivenFirstWin = p(RedBullWinsSecond, such_that(RedBullWinsFirst, NGPIGP))
RedBullWinsSecondGivenFirstWin
# Out:
# 0.31911357340720226

# %%
def RedBullWinsAtLeastOne(outcome) : return outcome[:2] == 'MV' or outcome[:2] == 'SP' or outcome[2:] == 'MV' or outcome[2:] == 'SP'
def RedBullWinsBoth(outcome) : return (outcome[:2] == 'MV' or outcome[:2] == 'SP') and (outcome[2:] == 'MV' or outcome[2:] == 'SP')
RedBullWinsBothGivenAtLeastOneWin = p(RedBullWinsBoth, such_that(RedBullWinsAtLeastOne, NGPIGP))
RedBullWinsBothGivenAtLeastOneWin
# Out:
# 0.18984838497033615

# %% [markdown]
# For Ferrari

# %%
def FerrariWinsFirst(outcome) : return outcome[:2] == 'CL' or outcome[:2] == 'CS'
def FerrariWinsSecond(outcome) : return outcome[2:] == 'CL' or outcome[2:] == 'CS'
FerrariWinsSecondGivenFirstWin = p(FerrariWinsSecond, such_that(FerrariWinsFirst, NGPIGP))
FerrariWinsSecondGivenFirstWin
# Out:
# 0.24321329639889197

# %%
def FerrariWinsAtLeastOne(outcome) : return outcome[:2] == 'CL' or outcome[:2] == 'CS' or outcome[2:] == 'CL' or outcome[2:] == 'CS'
def FerrariWinsBoth(outcome) : return (outcome[:2] == 'CL' or outcome[:2] == 'CS') and (outcome[2:] == 'CL' or outcome[2:] == 'CS')
FerrariWinsBothGivenAtLeastOneWin = p(FerrariWinsBoth, such_that(FerrariWinsAtLeastOne, NGPIGP))
FerrariWinsBothGivenAtLeastOneWin
# Out:
# 0.13844213181961526

# %% [markdown]
# For Mercedes

# %%
def MercedesWinsFirst(outcome) : return outcome[:2] == 'LH' or outcome[:2] == 'GR'
def MercedesWinsSecond(outcome) : return outcome[2:] == 'LH' or outcome[2:] == 'GR'
MercedesWinsSecondGivenFirstWin = p(MercedesWinsSecond, such_that(MercedesWinsFirst, NGPIGP))
MercedesWinsSecondGivenFirstWin
# Out:
# 0.2066481994459834

# %%
def MercedesWinsAtLeastOne(outcome) : return outcome[:2] == 'LH' or outcome[:2] == 'GR' or outcome[2:] == 'LH' or outcome[2:] == 'GR'
def MercedesWinsBoth(outcome) : return (outcome[:2] == 'LH' or outcome[:2] == 'GR') and (outcome[2:] == 'LH' or outcome[2:] == 'GR')
MercedesWinsBothGivenAtLeastOneWin = p(MercedesWinsBoth, such_that(MercedesWinsAtLeastOne, NGPIGP))
MercedesWinsBothGivenAtLeastOneWin
# Out:
# 0.11523015137472958

# %% [markdown]
# For Alpine Renault

# %%
def ARWinsFirst(outcome) : return outcome[:2] == 'EO' or outcome[:2] == 'FA'
def ARWinsSecond(outcome) : return outcome[2:] == 'EO' or outcome[2:] == 'FA'
ARWinsSecondGivenFirstWin = p(ARWinsSecond, such_that(ARWinsFirst, NGPIGP))
ARWinsSecondGivenFirstWin
# Out:
# 0.06925207756232689

# %%
def ARWinsAtLeastOne(outcome) : return outcome[:2] == 'EO' or outcome[:2] == 'FA' or outcome[2:] == 'EO' or outcome[2:] == 'FA'
def ARWinsBoth(outcome) : return (outcome[:2] == 'EO' or outcome[:2] == 'FA') and (outcome[2:] == 'EO' or outcome[2:] == 'FA')
ARWinsBothGivenAtLeastOneWin = p(ARWinsBoth, such_that(ARWinsAtLeastOne, NGPIGP))
ARWinsBothGivenAtLeastOneWin
# Out:
# 0.035868005738880916

# %% [markdown]
# ANSWER 3 :

# %%
W = ProbDist(
    RA = 0.2,
    SU = 0.2,
    CL = 0.2,
    SN = 0.2,
    FO = 0.2
    )
W
# Out:
# {'RA': 0.2, 'SU': 0.2, 'CL': 0.2, 'SN': 0.2, 'FO': 0.2}

# %%
NGPIGPW = ProbDist({a + b + c + d: NGP[a]*W[b]*IGP[c]*W[d] for a in NGP for b in W for c in IGP for d in W})
NGPIGPW
# Out:
# {'MVRAMVRA': 0.0014276256320930253,
#  'MVRAMVSU': 0.0014276256320930253,
#  'MVRAMVCL': 0.0014276256320930253,
#  'MVRAMVSN': 0.0014276256320930253,
#  'MVRAMVFO': 0.0014276256320930253,
#  'MVRACLRA': 0.0009922207472318095,
#  'MVRACLSU': 0.0009922207472318095,
#  'MVRACLCL': 0.0009922207472318095,
#  'MVRACLSN': 0.0009922207472318095,
#  'MVRACLFO': 0.0009922207472318095,
#  'MVRASPRA': 0.0009838475763690937,
#  'MVRASPSU': 0.0009838475763690937,
#  'MVRASPCL': 0.0009838475763690937,
#  'MVRASPSN': 0.0009838475763690937,
#  'MVRASPFO': 0.0009838475763690937,
#  'MVRAGRRA': 0.0008498768425656428,
#  'MVRAGRSU': 0.0008498768425656428,
#  'MVRAGRCL': 0.0008498768425656428,
#  'MVRAGRSN': 0.0008498768425656428,
#  'MVRAGRFO': 0.0008498768425656428,
#  'MVRACSRA': 0.0008456902571342849,
#  'MVRACSSU': 0.0008456902571342849,
#  'MVRACSCL': 0.0008456902571342849,
#  'MVRACSSN': 0.0008456902571342849,
#  'MVRACSFO': 0.0008456902571342849,
#  'MVRALHRA': 0.0007117195233308338,
#  'MVRALHSU': 0.0007117195233308338,
#  'MVRALHCL': 0.0007117195233308338,
#  'MVRALHSN': 0.0007117195233308338,
#  'MVRALHFO': 0.0007117195233308338,
#  'MVRALNRA': 0.0004186585431357846,
#  'MVRALNSU': 0.0004186585431357846,
#  'MVRALNCL': 0.0004186585431357846,
#  'MVRALNSN': 0.0004186585431357846,
#  'MVRALNFO': 0.0004186585431357846,
#  'MVRAEORA': 0.00027631463846961783,
#  'MVRAEOSU': 0.00027631463846961783,
#  'MVRAEOCL': 0.00027631463846961783,
#  'MVRAEOSN': 0.00027631463846961783,
#  'MVRAEOFO': 0.00027631463846961783,
#  'MVRAFARA': 0.00024700854045011294,
#  'MVRAFASU': 0.00024700854045011294,
#  'MVRAFACL': 0.00024700854045011294,
#  'MVRAFASN': 0.00024700854045011294,
#  'MVRAFAFO': 0.00024700854045011294,
#  'MVRAVBRA': 0.00019258292984246093,
#  'MVRAVBSU': 0.00019258292984246093,
#  'MVRAVBCL': 0.00019258292984246093,
#  'MVRAVBSN': 0.00019258292984246093,
#  'MVRAVBFO': 0.00019258292984246093,
#  'MVRADRRA': 0.00012141097750937754,
#  'MVRADRSU': 0.00012141097750937754,
#  'MVRADRCL': 0.00012141097750937754,
#  'MVRADRSN': 0.00012141097750937754,
#  'MVRADRFO': 0.00012141097750937754,
#  'MVRASVRA': 0.00010047805035258829,
#  'MVRASVSU': 0.00010047805035258829,
#  'MVRASVCL': 0.00010047805035258829,
#  'MVRASVSN': 0.00010047805035258829,
#  'MVRASVFO': 0.00010047805035258829,
#  'MVRAPGRA': 9.629146492123046e-05,
#  'MVRAPGSU': 9.629146492123046e-05,
#  'MVRAPGCL': 9.629146492123046e-05,
#  'MVRAPGSN': 9.629146492123046e-05,
#  'MVRAPGFO': 9.629146492123046e-05,
#  'MVRAKMRA': 9.210487948987261e-05,
#  'MVRAKMSU': 9.210487948987261e-05,
#  'MVRAKMCL': 9.210487948987261e-05,
#  'MVRAKMSN': 9.210487948987261e-05,
#  'MVRAKMFO': 9.210487948987261e-05,
#  'MVRALSRA': 5.4425610607652e-05,
#  'MVRALSSU': 5.4425610607652e-05,
#  'MVRALSCL': 5.4425610607652e-05,
#  'MVRALSSN': 5.4425610607652e-05,
#  'MVRALSFO': 5.4425610607652e-05,
#  'MVRAMSRA': 5.0239025176294146e-05,
#  'MVRAMSSU': 5.0239025176294146e-05,
#  'MVRAMSCL': 5.0239025176294146e-05,
#  'MVRAMSSN': 5.0239025176294146e-05,
#  'MVRAMSFO': 5.0239025176294146e-05,
#  'MVRAYTRA': 4.6052439744936305e-05,
#  'MVRAYTSU': 4.6052439744936305e-05,
#  'MVRAYTCL': 4.6052439744936305e-05,
#  'MVRAYTSN': 4.6052439744936305e-05,
#  'MVRAYTFO': 4.6052439744936305e-05,
#  'MVRAZGRA': 2.5119512588147073e-05,
#  'MVRAZGSU': 2.5119512588147073e-05,
#  'MVRAZGCL': 2.5119512588147073e-05,
#  'MVRAZGSN': 2.5119512588147073e-05,
#  'MVRAZGFO': 2.5119512588147073e-05,
#  'MVRAAARA': 1.674634172543138e-05,
#  'MVRAAASU': 1.674634172543138e-05,
#  'MVRAAACL': 1.674634172543138e-05,
#  'MVRAAASN': 1.674634172543138e-05,
#  'MVRAAAFO': 1.674634172543138e-05,
#  'MVRANVRA': 8.37317086271569e-06,
#  'MVRANVSU': 8.37317086271569e-06,
#  'MVRANVCL': 8.37317086271569e-06,
#  'MVRANVSN': 8.37317086271569e-06,
#  'MVRANVFO': 8.37317086271569e-06,
#  'MVRANLRA': 0.0,
#  'MVRANLSU': 0.0,
#  'MVRANLCL': 0.0,
#  'MVRANLSN': 0.0,
#  'MVRANLFO': 0.0,
#  'MVRANHRA': 0.0,
#  'MVRANHSU': 0.0,
#  'MVRANHCL': 0.0,
#  'MVRANHSN': 0.0,
#  'MVRANHFO': 0.0,
#  'MVSUMVRA': 0.0014276256320930253,
#  'MVSUMVSU': 0.0014276256320930253,
#  'MVSUMVCL': 0.0014276256320930253,
#  'MVSUMVSN': 0.0014276256320930253,
#  'MVSUMVFO': 0.0014276256320930253,
#  'MVSUCLRA': 0.0009922207472318095,
#  'MVSUCLSU': 0.0009922207472318095,
#  'MVSUCLCL': 0.0009922207472318095,
#  'MVSUCLSN': 0.0009922207472318095,
#  'MVSUCLFO': 0.0009922207472318095,
#  'MVSUSPRA': 0.0009838475763690937,
#  'MVSUSPSU': 0.0009838475763690937,
#  'MVSUSPCL': 0.0009838475763690937,
#  'MVSUSPSN': 0.0009838475763690937,
#  'MVSUSPFO': 0.0009838475763690937,
#  'MVSUGRRA': 0.0008498768425656428,
#  'MVSUGRSU': 0.0008498768425656428,
#  'MVSUGRCL': 0.0008498768425656428,
#  'MVSUGRSN': 0.0008498768425656428,
#  'MVSUGRFO': 0.0008498768425656428,
#  'MVSUCSRA': 0.0008456902571342849,
#  'MVSUCSSU': 0.0008456902571342849,
#  'MVSUCSCL': 0.0008456902571342849,
#  'MVSUCSSN': 0.0008456902571342849,
#  'MVSUCSFO': 0.0008456902571342849,
#  'MVSULHRA': 0.0007117195233308338,
#  'MVSULHSU': 0.0007117195233308338,
#  'MVSULHCL': 0.0007117195233308338,
#  'MVSULHSN': 0.0007117195233308338,
#  'MVSULHFO': 0.0007117195233308338,
#  'MVSULNRA': 0.0004186585431357846,
#  'MVSULNSU': 0.0004186585431357846,
#  'MVSULNCL': 0.0004186585431357846,
#  'MVSULNSN': 0.0004186585431357846,
#  'MVSULNFO': 0.0004186585431357846,
#  'MVSUEORA': 0.00027631463846961783,
#  'MVSUEOSU': 0.00027631463846961783,
#  'MVSUEOCL': 0.00027631463846961783,
#  'MVSUEOSN': 0.00027631463846961783,
#  'MVSUEOFO': 0.00027631463846961783,
#  'MVSUFARA': 0.00024700854045011294,
#  'MVSUFASU': 0.00024700854045011294,
#  'MVSUFACL': 0.00024700854045011294,
#  'MVSUFASN': 0.00024700854045011294,
#  'MVSUFAFO': 0.00024700854045011294,
#  'MVSUVBRA': 0.00019258292984246093,
#  'MVSUVBSU': 0.00019258292984246093,
#  'MVSUVBCL': 0.00019258292984246093,
#  'MVSUVBSN': 0.00019258292984246093,
#  'MVSUVBFO': 0.00019258292984246093,
#  'MVSUDRRA': 0.00012141097750937754,
#  'MVSUDRSU': 0.00012141097750937754,
#  'MVSUDRCL': 0.00012141097750937754,
#  'MVSUDRSN': 0.00012141097750937754,
#  'MVSUDRFO': 0.00012141097750937754,
#  'MVSUSVRA': 0.00010047805035258829,
#  'MVSUSVSU': 0.00010047805035258829,
#  'MVSUSVCL': 0.00010047805035258829,
#  'MVSUSVSN': 0.00010047805035258829,
#  'MVSUSVFO': 0.00010047805035258829,
#  'MVSUPGRA': 9.629146492123046e-05,
#  'MVSUPGSU': 9.629146492123046e-05,
#  'MVSUPGCL': 9.629146492123046e-05,
#  'MVSUPGSN': 9.629146492123046e-05,
#  'MVSUPGFO': 9.629146492123046e-05,
#  'MVSUKMRA': 9.210487948987261e-05,
#  'MVSUKMSU': 9.210487948987261e-05,
#  'MVSUKMCL': 9.210487948987261e-05,
#  'MVSUKMSN': 9.210487948987261e-05,
#  'MVSUKMFO': 9.210487948987261e-05,
#  'MVSULSRA': 5.4425610607652e-05,
#  'MVSULSSU': 5.4425610607652e-05,
#  'MVSULSCL': 5.4425610607652e-05,
#  'MVSULSSN': 5.4425610607652e-05,
#  'MVSULSFO': 5.4425610607652e-05,
#  'MVSUMSRA': 5.0239025176294146e-05,
#  'MVSUMSSU': 5.0239025176294146e-05,
#  'MVSUMSCL': 5.0239025176294146e-05,
#  'MVSUMSSN': 5.0239025176294146e-05,
#  'MVSUMSFO': 5.0239025176294146e-05,
#  'MVSUYTRA': 4.6052439744936305e-05,
#  'MVSUYTSU': 4.6052439744936305e-05,
#  'MVSUYTCL': 4.6052439744936305e-05,
#  'MVSUYTSN': 4.6052439744936305e-05,
#  'MVSUYTFO': 4.6052439744936305e-05,
#  'MVSUZGRA': 2.5119512588147073e-05,
#  'MVSUZGSU': 2.5119512588147073e-05,
#  'MVSUZGCL': 2.5119512588147073e-05,
#  'MVSUZGSN': 2.5119512588147073e-05,
#  'MVSUZGFO': 2.5119512588147073e-05,
#  'MVSUAARA': 1.674634172543138e-05,
#  'MVSUAASU': 1.674634172543138e-05,
#  'MVSUAACL': 1.674634172543138e-05,
#  'MVSUAASN': 1.674634172543138e-05,
#  'MVSUAAFO': 1.674634172543138e-05,
#  'MVSUNVRA': 8.37317086271569e-06,
#  'MVSUNVSU': 8.37317086271569e-06,
#  'MVSUNVCL': 8.37317086271569e-06,
#  'MVSUNVSN': 8.37317086271569e-06,
#  'MVSUNVFO': 8.37317086271569e-06,
#  'MVSUNLRA': 0.0,
#  'MVSUNLSU': 0.0,
#  'MVSUNLCL': 0.0,
#  'MVSUNLSN': 0.0,
#  'MVSUNLFO': 0.0,
#  'MVSUNHRA': 0.0,
#  'MVSUNHSU': 0.0,
#  'MVSUNHCL': 0.0,
#  'MVSUNHSN': 0.0,
#  'MVSUNHFO': 0.0,
#  'MVCLMVRA': 0.0014276256320930253,
#  'MVCLMVSU': 0.0014276256320930253,
#  'MVCLMVCL': 0.0014276256320930253,
#  'MVCLMVSN': 0.0014276256320930253,
#  'MVCLMVFO': 0.0014276256320930253,
#  'MVCLCLRA': 0.0009922207472318095,
#  'MVCLCLSU': 0.0009922207472318095,
#  'MVCLCLCL': 0.0009922207472318095,
#  'MVCLCLSN': 0.0009922207472318095,
#  'MVCLCLFO': 0.0009922207472318095,
#  'MVCLSPRA': 0.0009838475763690937,
#  'MVCLSPSU': 0.0009838475763690937,
#  'MVCLSPCL': 0.0009838475763690937,
#  'MVCLSPSN': 0.0009838475763690937,
#  'MVCLSPFO': 0.0009838475763690937,
#  'MVCLGRRA': 0.0008498768425656428,
#  'MVCLGRSU': 0.0008498768425656428,
#  'MVCLGRCL': 0.0008498768425656428,
#  'MVCLGRSN': 0.0008498768425656428,
#  'MVCLGRFO': 0.0008498768425656428,
#  'MVCLCSRA': 0.0008456902571342849,
#  'MVCLCSSU': 0.0008456902571342849,
#  'MVCLCSCL': 0.0008456902571342849,
#  'MVCLCSSN': 0.0008456902571342849,
#  'MVCLCSFO': 0.0008456902571342849,
#  'MVCLLHRA': 0.0007117195233308338,
#  'MVCLLHSU': 0.0007117195233308338,
#  'MVCLLHCL': 0.0007117195233308338,
#  'MVCLLHSN': 0.0007117195233308338,
#  'MVCLLHFO': 0.0007117195233308338,
#  'MVCLLNRA': 0.0004186585431357846,
#  'MVCLLNSU': 0.0004186585431357846,
#  'MVCLLNCL': 0.0004186585431357846,
#  'MVCLLNSN': 0.0004186585431357846,
#  'MVCLLNFO': 0.0004186585431357846,
#  'MVCLEORA': 0.00027631463846961783,
#  'MVCLEOSU': 0.00027631463846961783,
#  'MVCLEOCL': 0.00027631463846961783,
#  'MVCLEOSN': 0.00027631463846961783,
#  'MVCLEOFO': 0.00027631463846961783,
#  'MVCLFARA': 0.00024700854045011294,
#  'MVCLFASU': 0.00024700854045011294,
#  'MVCLFACL': 0.00024700854045011294,
#  'MVCLFASN': 0.00024700854045011294,
#  'MVCLFAFO': 0.00024700854045011294,
#  'MVCLVBRA': 0.00019258292984246093,
#  'MVCLVBSU': 0.00019258292984246093,
#  'MVCLVBCL': 0.00019258292984246093,
#  'MVCLVBSN': 0.00019258292984246093,
#  'MVCLVBFO': 0.00019258292984246093,
#  'MVCLDRRA': 0.00012141097750937754,
#  'MVCLDRSU': 0.00012141097750937754,
#  'MVCLDRCL': 0.00012141097750937754,
#  'MVCLDRSN': 0.00012141097750937754,
#  'MVCLDRFO': 0.00012141097750937754,
#  'MVCLSVRA': 0.00010047805035258829,
#  'MVCLSVSU': 0.00010047805035258829,
#  'MVCLSVCL': 0.00010047805035258829,
#  'MVCLSVSN': 0.00010047805035258829,
#  'MVCLSVFO': 0.00010047805035258829,
#  'MVCLPGRA': 9.629146492123046e-05,
#  'MVCLPGSU': 9.629146492123046e-05,
#  'MVCLPGCL': 9.629146492123046e-05,
#  'MVCLPGSN': 9.629146492123046e-05,
#  'MVCLPGFO': 9.629146492123046e-05,
#  'MVCLKMRA': 9.210487948987261e-05,
#  'MVCLKMSU': 9.210487948987261e-05,
#  'MVCLKMCL': 9.210487948987261e-05,
#  'MVCLKMSN': 9.210487948987261e-05,
#  'MVCLKMFO': 9.210487948987261e-05,
#  'MVCLLSRA': 5.4425610607652e-05,
#  'MVCLLSSU': 5.4425610607652e-05,
#  'MVCLLSCL': 5.4425610607652e-05,
#  'MVCLLSSN': 5.4425610607652e-05,
#  'MVCLLSFO': 5.4425610607652e-05,
#  'MVCLMSRA': 5.0239025176294146e-05,
#  'MVCLMSSU': 5.0239025176294146e-05,
#  'MVCLMSCL': 5.0239025176294146e-05,
#  'MVCLMSSN': 5.0239025176294146e-05,
#  'MVCLMSFO': 5.0239025176294146e-05,
#  'MVCLYTRA': 4.6052439744936305e-05,
#  'MVCLYTSU': 4.6052439744936305e-05,
#  'MVCLYTCL': 4.6052439744936305e-05,
#  'MVCLYTSN': 4.6052439744936305e-05,
#  'MVCLYTFO': 4.6052439744936305e-05,
#  'MVCLZGRA': 2.5119512588147073e-05,
#  'MVCLZGSU': 2.5119512588147073e-05,
#  'MVCLZGCL': 2.5119512588147073e-05,
#  'MVCLZGSN': 2.5119512588147073e-05,
#  'MVCLZGFO': 2.5119512588147073e-05,
#  'MVCLAARA': 1.674634172543138e-05,
#  'MVCLAASU': 1.674634172543138e-05,
#  'MVCLAACL': 1.674634172543138e-05,
#  'MVCLAASN': 1.674634172543138e-05,
#  'MVCLAAFO': 1.674634172543138e-05,
#  'MVCLNVRA': 8.37317086271569e-06,
#  'MVCLNVSU': 8.37317086271569e-06,
#  'MVCLNVCL': 8.37317086271569e-06,
#  'MVCLNVSN': 8.37317086271569e-06,
#  'MVCLNVFO': 8.37317086271569e-06,
#  'MVCLNLRA': 0.0,
#  'MVCLNLSU': 0.0,
#  'MVCLNLCL': 0.0,
#  'MVCLNLSN': 0.0,
#  'MVCLNLFO': 0.0,
#  'MVCLNHRA': 0.0,
#  'MVCLNHSU': 0.0,
#  'MVCLNHCL': 0.0,
#  'MVCLNHSN': 0.0,
#  'MVCLNHFO': 0.0,
#  'MVSNMVRA': 0.0014276256320930253,
#  'MVSNMVSU': 0.0014276256320930253,
#  'MVSNMVCL': 0.0014276256320930253,
#  'MVSNMVSN': 0.0014276256320930253,
#  'MVSNMVFO': 0.0014276256320930253,
#  'MVSNCLRA': 0.0009922207472318095,
#  'MVSNCLSU': 0.0009922207472318095,
#  'MVSNCLCL': 0.0009922207472318095,
#  'MVSNCLSN': 0.0009922207472318095,
#  'MVSNCLFO': 0.0009922207472318095,
#  'MVSNSPRA': 0.0009838475763690937,
#  'MVSNSPSU': 0.0009838475763690937,
#  'MVSNSPCL': 0.0009838475763690937,
#  'MVSNSPSN': 0.0009838475763690937,
#  'MVSNSPFO': 0.0009838475763690937,
#  'MVSNGRRA': 0.0008498768425656428,
#  'MVSNGRSU': 0.0008498768425656428,
#  'MVSNGRCL': 0.0008498768425656428,
#  'MVSNGRSN': 0.0008498768425656428,
#  'MVSNGRFO': 0.0008498768425656428,
#  'MVSNCSRA': 0.0008456902571342849,
#  'MVSNCSSU': 0.0008456902571342849,
#  'MVSNCSCL': 0.0008456902571342849,
#  'MVSNCSSN': 0.0008456902571342849,
#  'MVSNCSFO': 0.0008456902571342849,
#  'MVSNLHRA': 0.0007117195233308338,
#  'MVSNLHSU': 0.0007117195233308338,
#  'MVSNLHCL': 0.0007117195233308338,
#  'MVSNLHSN': 0.0007117195233308338,
#  'MVSNLHFO': 0.0007117195233308338,
#  'MVSNLNRA': 0.0004186585431357846,
#  'MVSNLNSU': 0.0004186585431357846,
#  'MVSNLNCL': 0.0004186585431357846,
#  'MVSNLNSN': 0.0004186585431357846,
#  'MVSNLNFO': 0.0004186585431357846,
#  'MVSNEORA': 0.00027631463846961783,
#  'MVSNEOSU': 0.00027631463846961783,
#  'MVSNEOCL': 0.00027631463846961783,
#  'MVSNEOSN': 0.00027631463846961783,
#  'MVSNEOFO': 0.00027631463846961783,
#  'MVSNFARA': 0.00024700854045011294,
#  'MVSNFASU': 0.00024700854045011294,
#  'MVSNFACL': 0.00024700854045011294,
#  'MVSNFASN': 0.00024700854045011294,
#  'MVSNFAFO': 0.00024700854045011294,
#  'MVSNVBRA': 0.00019258292984246093,
#  'MVSNVBSU': 0.00019258292984246093,
#  'MVSNVBCL': 0.00019258292984246093,
#  'MVSNVBSN': 0.00019258292984246093,
#  'MVSNVBFO': 0.00019258292984246093,
#  'MVSNDRRA': 0.00012141097750937754,
#  'MVSNDRSU': 0.00012141097750937754,
#  'MVSNDRCL': 0.00012141097750937754,
#  'MVSNDRSN': 0.00012141097750937754,
#  'MVSNDRFO': 0.00012141097750937754,
#  'MVSNSVRA': 0.00010047805035258829,
#  'MVSNSVSU': 0.00010047805035258829,
#  'MVSNSVCL': 0.00010047805035258829,
#  'MVSNSVSN': 0.00010047805035258829,
#  'MVSNSVFO': 0.00010047805035258829,
#  'MVSNPGRA': 9.629146492123046e-05,
#  'MVSNPGSU': 9.629146492123046e-05,
#  'MVSNPGCL': 9.629146492123046e-05,
#  'MVSNPGSN': 9.629146492123046e-05,
#  'MVSNPGFO': 9.629146492123046e-05,
#  'MVSNKMRA': 9.210487948987261e-05,
#  'MVSNKMSU': 9.210487948987261e-05,
#  'MVSNKMCL': 9.210487948987261e-05,
#  'MVSNKMSN': 9.210487948987261e-05,
#  'MVSNKMFO': 9.210487948987261e-05,
#  'MVSNLSRA': 5.4425610607652e-05,
#  'MVSNLSSU': 5.4425610607652e-05,
#  'MVSNLSCL': 5.4425610607652e-05,
#  'MVSNLSSN': 5.4425610607652e-05,
#  'MVSNLSFO': 5.4425610607652e-05,
#  'MVSNMSRA': 5.0239025176294146e-05,
#  'MVSNMSSU': 5.0239025176294146e-05,
#  'MVSNMSCL': 5.0239025176294146e-05,
#  'MVSNMSSN': 5.0239025176294146e-05,
#  'MVSNMSFO': 5.0239025176294146e-05,
#  'MVSNYTRA': 4.6052439744936305e-05,
#  'MVSNYTSU': 4.6052439744936305e-05,
#  'MVSNYTCL': 4.6052439744936305e-05,
#  'MVSNYTSN': 4.6052439744936305e-05,
#  'MVSNYTFO': 4.6052439744936305e-05,
#  'MVSNZGRA': 2.5119512588147073e-05,
#  'MVSNZGSU': 2.5119512588147073e-05,
#  'MVSNZGCL': 2.5119512588147073e-05,
#  'MVSNZGSN': 2.5119512588147073e-05,
#  'MVSNZGFO': 2.5119512588147073e-05,
#  'MVSNAARA': 1.674634172543138e-05,
#  'MVSNAASU': 1.674634172543138e-05,
#  'MVSNAACL': 1.674634172543138e-05,
#  'MVSNAASN': 1.674634172543138e-05,
#  'MVSNAAFO': 1.674634172543138e-05,
#  'MVSNNVRA': 8.37317086271569e-06,
#  'MVSNNVSU': 8.37317086271569e-06,
#  'MVSNNVCL': 8.37317086271569e-06,
#  'MVSNNVSN': 8.37317086271569e-06,
#  'MVSNNVFO': 8.37317086271569e-06,
#  'MVSNNLRA': 0.0,
#  'MVSNNLSU': 0.0,
#  'MVSNNLCL': 0.0,
#  'MVSNNLSN': 0.0,
#  'MVSNNLFO': 0.0,
#  'MVSNNHRA': 0.0,
#  'MVSNNHSU': 0.0,
#  'MVSNNHCL': 0.0,
#  'MVSNNHSN': 0.0,
#  'MVSNNHFO': 0.0,
#  'MVFOMVRA': 0.0014276256320930253,
#  'MVFOMVSU': 0.0014276256320930253,
#  'MVFOMVCL': 0.0014276256320930253,
#  'MVFOMVSN': 0.0014276256320930253,
#  'MVFOMVFO': 0.0014276256320930253,
#  'MVFOCLRA': 0.0009922207472318095,
#  'MVFOCLSU': 0.0009922207472318095,
#  'MVFOCLCL': 0.0009922207472318095,
#  'MVFOCLSN': 0.0009922207472318095,
#  'MVFOCLFO': 0.0009922207472318095,
#  'MVFOSPRA': 0.0009838475763690937,
#  'MVFOSPSU': 0.0009838475763690937,
#  'MVFOSPCL': 0.0009838475763690937,
#  'MVFOSPSN': 0.0009838475763690937,
#  'MVFOSPFO': 0.0009838475763690937,
#  'MVFOGRRA': 0.0008498768425656428,
#  'MVFOGRSU': 0.0008498768425656428,
#  'MVFOGRCL': 0.0008498768425656428,
#  'MVFOGRSN': 0.0008498768425656428,
#  'MVFOGRFO': 0.0008498768425656428,
#  'MVFOCSRA': 0.0008456902571342849,
#  'MVFOCSSU': 0.0008456902571342849,
#  'MVFOCSCL': 0.0008456902571342849,
#  'MVFOCSSN': 0.0008456902571342849,
#  'MVFOCSFO': 0.0008456902571342849,
#  'MVFOLHRA': 0.0007117195233308338,
#  'MVFOLHSU': 0.0007117195233308338,
#  'MVFOLHCL': 0.0007117195233308338,
#  'MVFOLHSN': 0.0007117195233308338,
#  'MVFOLHFO': 0.0007117195233308338,
#  'MVFOLNRA': 0.0004186585431357846,
#  'MVFOLNSU': 0.0004186585431357846,
#  'MVFOLNCL': 0.0004186585431357846,
#  'MVFOLNSN': 0.0004186585431357846,
#  'MVFOLNFO': 0.0004186585431357846,
#  'MVFOEORA': 0.00027631463846961783,
#  'MVFOEOSU': 0.00027631463846961783,
#  'MVFOEOCL': 0.00027631463846961783,
#  'MVFOEOSN': 0.00027631463846961783,
#  'MVFOEOFO': 0.00027631463846961783,
#  'MVFOFARA': 0.00024700854045011294,
#  'MVFOFASU': 0.00024700854045011294,
#  'MVFOFACL': 0.00024700854045011294,
#  'MVFOFASN': 0.00024700854045011294,
#  'MVFOFAFO': 0.00024700854045011294,
#  'MVFOVBRA': 0.00019258292984246093,
#  'MVFOVBSU': 0.00019258292984246093,
#  'MVFOVBCL': 0.00019258292984246093,
#  'MVFOVBSN': 0.00019258292984246093,
#  'MVFOVBFO': 0.00019258292984246093,
#  'MVFODRRA': 0.00012141097750937754,
#  'MVFODRSU': 0.00012141097750937754,
#  'MVFODRCL': 0.00012141097750937754,
#  'MVFODRSN': 0.00012141097750937754,
#  'MVFODRFO': 0.00012141097750937754,
#  'MVFOSVRA': 0.00010047805035258829,
#  'MVFOSVSU': 0.00010047805035258829,
#  'MVFOSVCL': 0.00010047805035258829,
#  'MVFOSVSN': 0.00010047805035258829,
#  'MVFOSVFO': 0.00010047805035258829,
#  'MVFOPGRA': 9.629146492123046e-05,
#  'MVFOPGSU': 9.629146492123046e-05,
#  'MVFOPGCL': 9.629146492123046e-05,
#  'MVFOPGSN': 9.629146492123046e-05,
#  'MVFOPGFO': 9.629146492123046e-05,
#  'MVFOKMRA': 9.210487948987261e-05,
#  'MVFOKMSU': 9.210487948987261e-05,
#  'MVFOKMCL': 9.210487948987261e-05,
#  'MVFOKMSN': 9.210487948987261e-05,
#  'MVFOKMFO': 9.210487948987261e-05,
#  'MVFOLSRA': 5.4425610607652e-05,
#  'MVFOLSSU': 5.4425610607652e-05,
#  'MVFOLSCL': 5.4425610607652e-05,
#  'MVFOLSSN': 5.4425610607652e-05,
#  'MVFOLSFO': 5.4425610607652e-05,
#  'MVFOMSRA': 5.0239025176294146e-05,
#  'MVFOMSSU': 5.0239025176294146e-05,
#  'MVFOMSCL': 5.0239025176294146e-05,
#  'MVFOMSSN': 5.0239025176294146e-05,
#  'MVFOMSFO': 5.0239025176294146e-05,
#  'MVFOYTRA': 4.6052439744936305e-05,
#  'MVFOYTSU': 4.6052439744936305e-05,
#  'MVFOYTCL': 4.6052439744936305e-05,
#  'MVFOYTSN': 4.6052439744936305e-05,
#  'MVFOYTFO': 4.6052439744936305e-05,
#  'MVFOZGRA': 2.5119512588147073e-05,
#  'MVFOZGSU': 2.5119512588147073e-05,
#  'MVFOZGCL': 2.5119512588147073e-05,
#  'MVFOZGSN': 2.5119512588147073e-05,
#  'MVFOZGFO': 2.5119512588147073e-05,
#  'MVFOAARA': 1.674634172543138e-05,
#  'MVFOAASU': 1.674634172543138e-05,
#  'MVFOAACL': 1.674634172543138e-05,
#  'MVFOAASN': 1.674634172543138e-05,
#  'MVFOAAFO': 1.674634172543138e-05,
#  'MVFONVRA': 8.37317086271569e-06,
#  'MVFONVSU': 8.37317086271569e-06,
#  'MVFONVCL': 8.37317086271569e-06,
#  'MVFONVSN': 8.37317086271569e-06,
#  'MVFONVFO': 8.37317086271569e-06,
#  'MVFONLRA': 0.0,
#  'MVFONLSU': 0.0,
#  'MVFONLCL': 0.0,
#  'MVFONLSN': 0.0,
#  'MVFONLFO': 0.0,
#  'MVFONHRA': 0.0,
#  'MVFONHSU': 0.0,
#  'MVFONHCL': 0.0,
#  'MVFONHSN': 0.0,
#  'MVFONHFO': 0.0,
#  'CLRAMVRA': 0.0009922207472318095,
#  'CLRAMVSU': 0.0009922207472318095,
#  'CLRAMVCL': 0.0009922207472318095,
#  'CLRAMVSN': 0.0009922207472318095,
#  'CLRAMVFO': 0.0009922207472318095,
#  'CLRACLRA': 0.000689607968017416,
#  'CLRACLSU': 0.000689607968017416,
#  'CLRACLCL': 0.000689607968017416,
#  'CLRACLSN': 0.000689607968017416,
#  'CLRACLFO': 0.000689607968017416,
#  'CLRASPRA': 0.0006837884914940623,
#  'CLRASPSU': 0.0006837884914940623,
#  'CLRASPCL': 0.0006837884914940623,
#  'CLRASPSN': 0.0006837884914940623,
#  'CLRASPFO': 0.0006837884914940623,
#  'CLRAGRRA': 0.0005906768671204027,
#  'CLRAGRSU': 0.0005906768671204027,
#  'CLRAGRCL': 0.0005906768671204027,
#  'CLRAGRSN': 0.0005906768671204027,
#  'CLRAGRFO': 0.0005906768671204027,
#  'CLRACSRA': 0.0005877671288587259,
#  'CLRACSSU': 0.0005877671288587259,
#  'CLRACSCL': 0.0005877671288587259,
#  'CLRACSSN': 0.0005877671288587259,
#  'CLRACSFO': 0.0005877671288587259,
#  'CLRALHRA': 0.0004946555044850662,
#  'CLRALHSU': 0.0004946555044850662,
#  'CLRALHCL': 0.0004946555044850662,
#  'CLRALHSN': 0.0004946555044850662,
#  'CLRALHFO': 0.0004946555044850662,
#  'CLRALNRA': 0.000290973826167686,
#  'CLRALNSU': 0.000290973826167686,
#  'CLRALNCL': 0.000290973826167686,
#  'CLRALNSN': 0.000290973826167686,
#  'CLRALNFO': 0.000290973826167686,
#  'CLRAEORA': 0.0001920427252706728,
#  'CLRAEOSU': 0.0001920427252706728,
#  'CLRAEOCL': 0.0001920427252706728,
#  'CLRAEOSN': 0.0001920427252706728,
#  'CLRAEOFO': 0.0001920427252706728,
#  'CLRAFARA': 0.00017167455743893477,
#  'CLRAFASU': 0.00017167455743893477,
#  'CLRAFACL': 0.00017167455743893477,
#  'CLRAFASN': 0.00017167455743893477,
#  'CLRAFAFO': 0.00017167455743893477,
#  'CLRAVBRA': 0.0001338479600371356,
#  'CLRAVBSU': 0.0001338479600371356,
#  'CLRAVBCL': 0.0001338479600371356,
#  'CLRAVBSN': 0.0001338479600371356,
#  'CLRAVBFO': 0.0001338479600371356,
#  'CLRADRRA': 8.438240958862896e-05,
#  'CLRADRSU': 8.438240958862896e-05,
#  'CLRADRCL': 8.438240958862896e-05,
#  'CLRADRSN': 8.438240958862896e-05,
#  'CLRADRFO': 8.438240958862896e-05,
#  'CLRASVRA': 6.983371828024464e-05,
#  'CLRASVSU': 6.983371828024464e-05,
#  'CLRASVCL': 6.983371828024464e-05,
#  'CLRASVSN': 6.983371828024464e-05,
#  'CLRASVFO': 6.983371828024464e-05,
#  'CLRAPGRA': 6.69239800185678e-05,
#  'CLRAPGSU': 6.69239800185678e-05,
#  'CLRAPGCL': 6.69239800185678e-05,
#  'CLRAPGSN': 6.69239800185678e-05,
#  'CLRAPGFO': 6.69239800185678e-05,
#  'CLRAKMRA': 6.401424175689093e-05,
#  'CLRAKMSU': 6.401424175689093e-05,
#  'CLRAKMCL': 6.401424175689093e-05,
#  'CLRAKMSN': 6.401424175689093e-05,
#  'CLRAKMFO': 6.401424175689093e-05,
#  'CLRALSRA': 3.7826597401799186e-05,
#  'CLRALSSU': 3.7826597401799186e-05,
#  'CLRALSCL': 3.7826597401799186e-05,
#  'CLRALSSN': 3.7826597401799186e-05,
#  'CLRALSFO': 3.7826597401799186e-05,
#  'CLRAMSRA': 3.491685914012232e-05,
#  'CLRAMSSU': 3.491685914012232e-05,
#  'CLRAMSCL': 3.491685914012232e-05,
#  'CLRAMSSN': 3.491685914012232e-05,
#  'CLRAMSFO': 3.491685914012232e-05,
#  'CLRAYTRA': 3.2007120878445464e-05,
#  'CLRAYTSU': 3.2007120878445464e-05,
#  'CLRAYTCL': 3.2007120878445464e-05,
#  'CLRAYTSN': 3.2007120878445464e-05,
#  'CLRAYTFO': 3.2007120878445464e-05,
#  'CLRAZGRA': 1.745842957006116e-05,
#  'CLRAZGSU': 1.745842957006116e-05,
#  'CLRAZGCL': 1.745842957006116e-05,
#  'CLRAZGSN': 1.745842957006116e-05,
#  'CLRAZGFO': 1.745842957006116e-05,
#  'CLRAAARA': 1.1638953046707443e-05,
#  'CLRAAASU': 1.1638953046707443e-05,
#  'CLRAAACL': 1.1638953046707443e-05,
#  'CLRAAASN': 1.1638953046707443e-05,
#  'CLRAAAFO': 1.1638953046707443e-05,
#  'CLRANVRA': 5.819476523353721e-06,
#  'CLRANVSU': 5.819476523353721e-06,
#  'CLRANVCL': 5.819476523353721e-06,
#  'CLRANVSN': 5.819476523353721e-06,
#  'CLRANVFO': 5.819476523353721e-06,
#  'CLRANLRA': 0.0,
#  'CLRANLSU': 0.0,
#  'CLRANLCL': 0.0,
#  'CLRANLSN': 0.0,
#  'CLRANLFO': 0.0,
#  'CLRANHRA': 0.0,
#  'CLRANHSU': 0.0,
#  'CLRANHCL': 0.0,
#  'CLRANHSN': 0.0,
#  'CLRANHFO': 0.0,
#  'CLSUMVRA': 0.0009922207472318095,
#  'CLSUMVSU': 0.0009922207472318095,
#  'CLSUMVCL': 0.0009922207472318095,
#  'CLSUMVSN': 0.0009922207472318095,
#  'CLSUMVFO': 0.0009922207472318095,
#  'CLSUCLRA': 0.000689607968017416,
#  'CLSUCLSU': 0.000689607968017416,
#  'CLSUCLCL': 0.000689607968017416,
#  'CLSUCLSN': 0.000689607968017416,
#  'CLSUCLFO': 0.000689607968017416,
#  'CLSUSPRA': 0.0006837884914940623,
#  'CLSUSPSU': 0.0006837884914940623,
#  'CLSUSPCL': 0.0006837884914940623,
#  'CLSUSPSN': 0.0006837884914940623,
#  'CLSUSPFO': 0.0006837884914940623,
#  'CLSUGRRA': 0.0005906768671204027,
#  'CLSUGRSU': 0.0005906768671204027,
#  'CLSUGRCL': 0.0005906768671204027,
#  'CLSUGRSN': 0.0005906768671204027,
#  'CLSUGRFO': 0.0005906768671204027,
#  'CLSUCSRA': 0.0005877671288587259,
#  'CLSUCSSU': 0.0005877671288587259,
#  'CLSUCSCL': 0.0005877671288587259,
#  'CLSUCSSN': 0.0005877671288587259,
#  'CLSUCSFO': 0.0005877671288587259,
#  'CLSULHRA': 0.0004946555044850662,
#  'CLSULHSU': 0.0004946555044850662,
#  'CLSULHCL': 0.0004946555044850662,
#  'CLSULHSN': 0.0004946555044850662,
#  'CLSULHFO': 0.0004946555044850662,
#  'CLSULNRA': 0.000290973826167686,
#  'CLSULNSU': 0.000290973826167686,
#  'CLSULNCL': 0.000290973826167686,
#  'CLSULNSN': 0.000290973826167686,
#  'CLSULNFO': 0.000290973826167686,
#  'CLSUEORA': 0.0001920427252706728,
#  'CLSUEOSU': 0.0001920427252706728,
#  'CLSUEOCL': 0.0001920427252706728,
#  'CLSUEOSN': 0.0001920427252706728,
#  'CLSUEOFO': 0.0001920427252706728,
#  'CLSUFARA': 0.00017167455743893477,
#  'CLSUFASU': 0.00017167455743893477,
#  'CLSUFACL': 0.00017167455743893477,
#  'CLSUFASN': 0.00017167455743893477,
#  'CLSUFAFO': 0.00017167455743893477,
#  'CLSUVBRA': 0.0001338479600371356,
#  'CLSUVBSU': 0.0001338479600371356,
#  'CLSUVBCL': 0.0001338479600371356,
#  'CLSUVBSN': 0.0001338479600371356,
#  'CLSUVBFO': 0.0001338479600371356,
#  'CLSUDRRA': 8.438240958862896e-05,
#  'CLSUDRSU': 8.438240958862896e-05,
#  'CLSUDRCL': 8.438240958862896e-05,
#  'CLSUDRSN': 8.438240958862896e-05,
#  'CLSUDRFO': 8.438240958862896e-05,
#  'CLSUSVRA': 6.983371828024464e-05,
#  'CLSUSVSU': 6.983371828024464e-05,
#  'CLSUSVCL': 6.983371828024464e-05,
#  'CLSUSVSN': 6.983371828024464e-05,
#  'CLSUSVFO': 6.983371828024464e-05,
#  'CLSUPGRA': 6.69239800185678e-05,
#  'CLSUPGSU': 6.69239800185678e-05,
#  'CLSUPGCL': 6.69239800185678e-05,
#  'CLSUPGSN': 6.69239800185678e-05,
#  'CLSUPGFO': 6.69239800185678e-05,
#  'CLSUKMRA': 6.401424175689093e-05,
#  'CLSUKMSU': 6.401424175689093e-05,
#  'CLSUKMCL': 6.401424175689093e-05,
#  'CLSUKMSN': 6.401424175689093e-05,
#  'CLSUKMFO': 6.401424175689093e-05,
#  'CLSULSRA': 3.7826597401799186e-05,
#  'CLSULSSU': 3.7826597401799186e-05,
#  'CLSULSCL': 3.7826597401799186e-05,
#  'CLSULSSN': 3.7826597401799186e-05,
#  'CLSULSFO': 3.7826597401799186e-05,
#  'CLSUMSRA': 3.491685914012232e-05,
#  'CLSUMSSU': 3.491685914012232e-05,
#  'CLSUMSCL': 3.491685914012232e-05,
#  'CLSUMSSN': 3.491685914012232e-05,
#  'CLSUMSFO': 3.491685914012232e-05,
#  'CLSUYTRA': 3.2007120878445464e-05,
#  'CLSUYTSU': 3.2007120878445464e-05,
#  'CLSUYTCL': 3.2007120878445464e-05,
#  'CLSUYTSN': 3.2007120878445464e-05,
#  'CLSUYTFO': 3.2007120878445464e-05,
#  'CLSUZGRA': 1.745842957006116e-05,
#  'CLSUZGSU': 1.745842957006116e-05,
#  'CLSUZGCL': 1.745842957006116e-05,
#  'CLSUZGSN': 1.745842957006116e-05,
#  'CLSUZGFO': 1.745842957006116e-05,
#  'CLSUAARA': 1.1638953046707443e-05,
#  'CLSUAASU': 1.1638953046707443e-05,
#  'CLSUAACL': 1.1638953046707443e-05,
#  'CLSUAASN': 1.1638953046707443e-05,
#  'CLSUAAFO': 1.1638953046707443e-05,
#  'CLSUNVRA': 5.819476523353721e-06,
#  'CLSUNVSU': 5.819476523353721e-06,
#  'CLSUNVCL': 5.819476523353721e-06,
#  'CLSUNVSN': 5.819476523353721e-06,
#  'CLSUNVFO': 5.819476523353721e-06,
#  'CLSUNLRA': 0.0,
#  'CLSUNLSU': 0.0,
#  'CLSUNLCL': 0.0,
#  'CLSUNLSN': 0.0,
#  'CLSUNLFO': 0.0,
#  'CLSUNHRA': 0.0,
#  'CLSUNHSU': 0.0,
#  'CLSUNHCL': 0.0,
#  'CLSUNHSN': 0.0,
#  'CLSUNHFO': 0.0,
#  'CLCLMVRA': 0.0009922207472318095,
#  'CLCLMVSU': 0.0009922207472318095,
#  'CLCLMVCL': 0.0009922207472318095,
#  'CLCLMVSN': 0.0009922207472318095,
#  'CLCLMVFO': 0.0009922207472318095,
#  'CLCLCLRA': 0.000689607968017416,
#  'CLCLCLSU': 0.000689607968017416,
#  'CLCLCLCL': 0.000689607968017416,
#  'CLCLCLSN': 0.000689607968017416,
#  'CLCLCLFO': 0.000689607968017416,
#  'CLCLSPRA': 0.0006837884914940623,
#  'CLCLSPSU': 0.0006837884914940623,
#  'CLCLSPCL': 0.0006837884914940623,
#  'CLCLSPSN': 0.0006837884914940623,
#  'CLCLSPFO': 0.0006837884914940623,
#  'CLCLGRRA': 0.0005906768671204027,
#  'CLCLGRSU': 0.0005906768671204027,
#  'CLCLGRCL': 0.0005906768671204027,
#  'CLCLGRSN': 0.0005906768671204027,
#  'CLCLGRFO': 0.0005906768671204027,
#  'CLCLCSRA': 0.0005877671288587259,
#  'CLCLCSSU': 0.0005877671288587259,
#  'CLCLCSCL': 0.0005877671288587259,
#  'CLCLCSSN': 0.0005877671288587259,
#  'CLCLCSFO': 0.0005877671288587259,
#  'CLCLLHRA': 0.0004946555044850662,
#  'CLCLLHSU': 0.0004946555044850662,
#  'CLCLLHCL': 0.0004946555044850662,
#  'CLCLLHSN': 0.0004946555044850662,
#  'CLCLLHFO': 0.0004946555044850662,
#  'CLCLLNRA': 0.000290973826167686,
#  'CLCLLNSU': 0.000290973826167686,
#  'CLCLLNCL': 0.000290973826167686,
#  'CLCLLNSN': 0.000290973826167686,
#  'CLCLLNFO': 0.000290973826167686,
#  'CLCLEORA': 0.0001920427252706728,
#  'CLCLEOSU': 0.0001920427252706728,
#  'CLCLEOCL': 0.0001920427252706728,
#  'CLCLEOSN': 0.0001920427252706728,
#  'CLCLEOFO': 0.0001920427252706728,
#  'CLCLFARA': 0.00017167455743893477,
#  'CLCLFASU': 0.00017167455743893477,
#  'CLCLFACL': 0.00017167455743893477,
#  'CLCLFASN': 0.00017167455743893477,
#  'CLCLFAFO': 0.00017167455743893477,
#  'CLCLVBRA': 0.0001338479600371356,
#  'CLCLVBSU': 0.0001338479600371356,
#  'CLCLVBCL': 0.0001338479600371356,
#  'CLCLVBSN': 0.0001338479600371356,
#  'CLCLVBFO': 0.0001338479600371356,
#  'CLCLDRRA': 8.438240958862896e-05,
#  'CLCLDRSU': 8.438240958862896e-05,
#  'CLCLDRCL': 8.438240958862896e-05,
#  'CLCLDRSN': 8.438240958862896e-05,
#  'CLCLDRFO': 8.438240958862896e-05,
#  'CLCLSVRA': 6.983371828024464e-05,
#  'CLCLSVSU': 6.983371828024464e-05,
#  'CLCLSVCL': 6.983371828024464e-05,
#  'CLCLSVSN': 6.983371828024464e-05,
#  'CLCLSVFO': 6.983371828024464e-05,
#  'CLCLPGRA': 6.69239800185678e-05,
#  'CLCLPGSU': 6.69239800185678e-05,
#  'CLCLPGCL': 6.69239800185678e-05,
#  'CLCLPGSN': 6.69239800185678e-05,
#  'CLCLPGFO': 6.69239800185678e-05,
#  'CLCLKMRA': 6.401424175689093e-05,
#  'CLCLKMSU': 6.401424175689093e-05,
#  'CLCLKMCL': 6.401424175689093e-05,
#  'CLCLKMSN': 6.401424175689093e-05,
#  'CLCLKMFO': 6.401424175689093e-05,
#  'CLCLLSRA': 3.7826597401799186e-05,
#  'CLCLLSSU': 3.7826597401799186e-05,
#  'CLCLLSCL': 3.7826597401799186e-05,
#  'CLCLLSSN': 3.7826597401799186e-05,
#  'CLCLLSFO': 3.7826597401799186e-05,
#  'CLCLMSRA': 3.491685914012232e-05,
#  'CLCLMSSU': 3.491685914012232e-05,
#  'CLCLMSCL': 3.491685914012232e-05,
#  'CLCLMSSN': 3.491685914012232e-05,
#  'CLCLMSFO': 3.491685914012232e-05,
#  'CLCLYTRA': 3.2007120878445464e-05,
#  'CLCLYTSU': 3.2007120878445464e-05,
#  'CLCLYTCL': 3.2007120878445464e-05,
#  'CLCLYTSN': 3.2007120878445464e-05,
#  'CLCLYTFO': 3.2007120878445464e-05,
#  'CLCLZGRA': 1.745842957006116e-05,
#  'CLCLZGSU': 1.745842957006116e-05,
#  'CLCLZGCL': 1.745842957006116e-05,
#  'CLCLZGSN': 1.745842957006116e-05,
#  'CLCLZGFO': 1.745842957006116e-05,
#  'CLCLAARA': 1.1638953046707443e-05,
#  'CLCLAASU': 1.1638953046707443e-05,
#  'CLCLAACL': 1.1638953046707443e-05,
#  'CLCLAASN': 1.1638953046707443e-05,
#  'CLCLAAFO': 1.1638953046707443e-05,
#  'CLCLNVRA': 5.819476523353721e-06,
#  'CLCLNVSU': 5.819476523353721e-06,
#  'CLCLNVCL': 5.819476523353721e-06,
#  'CLCLNVSN': 5.819476523353721e-06,
#  'CLCLNVFO': 5.819476523353721e-06,
#  'CLCLNLRA': 0.0,
#  'CLCLNLSU': 0.0,
#  'CLCLNLCL': 0.0,
#  'CLCLNLSN': 0.0,
#  'CLCLNLFO': 0.0,
#  'CLCLNHRA': 0.0,
#  'CLCLNHSU': 0.0,
#  'CLCLNHCL': 0.0,
#  'CLCLNHSN': 0.0,
#  'CLCLNHFO': 0.0,
#  'CLSNMVRA': 0.0009922207472318095,
#  'CLSNMVSU': 0.0009922207472318095,
#  'CLSNMVCL': 0.0009922207472318095,
#  'CLSNMVSN': 0.0009922207472318095,
#  'CLSNMVFO': 0.0009922207472318095,
#  'CLSNCLRA': 0.000689607968017416,
#  'CLSNCLSU': 0.000689607968017416,
#  'CLSNCLCL': 0.000689607968017416,
#  'CLSNCLSN': 0.000689607968017416,
#  'CLSNCLFO': 0.000689607968017416,
#  'CLSNSPRA': 0.0006837884914940623,
#  'CLSNSPSU': 0.0006837884914940623,
#  'CLSNSPCL': 0.0006837884914940623,
#  'CLSNSPSN': 0.0006837884914940623,
#  'CLSNSPFO': 0.0006837884914940623,
#  'CLSNGRRA': 0.0005906768671204027,
#  'CLSNGRSU': 0.0005906768671204027,
#  'CLSNGRCL': 0.0005906768671204027,
#  'CLSNGRSN': 0.0005906768671204027,
#  'CLSNGRFO': 0.0005906768671204027,
#  'CLSNCSRA': 0.0005877671288587259,
#  'CLSNCSSU': 0.0005877671288587259,
#  'CLSNCSCL': 0.0005877671288587259,
#  'CLSNCSSN': 0.0005877671288587259,
#  'CLSNCSFO': 0.0005877671288587259,
#  'CLSNLHRA': 0.0004946555044850662,
#  'CLSNLHSU': 0.0004946555044850662,
#  'CLSNLHCL': 0.0004946555044850662,
#  'CLSNLHSN': 0.0004946555044850662,
#  'CLSNLHFO': 0.0004946555044850662,
#  'CLSNLNRA': 0.000290973826167686,
#  'CLSNLNSU': 0.000290973826167686,
#  'CLSNLNCL': 0.000290973826167686,
#  'CLSNLNSN': 0.000290973826167686,
#  'CLSNLNFO': 0.000290973826167686,
#  'CLSNEORA': 0.0001920427252706728,
#  'CLSNEOSU': 0.0001920427252706728,
#  'CLSNEOCL': 0.0001920427252706728,
#  'CLSNEOSN': 0.0001920427252706728,
#  'CLSNEOFO': 0.0001920427252706728,
#  'CLSNFARA': 0.00017167455743893477,
#  'CLSNFASU': 0.00017167455743893477,
#  'CLSNFACL': 0.00017167455743893477,
#  'CLSNFASN': 0.00017167455743893477,
#  'CLSNFAFO': 0.00017167455743893477,
#  'CLSNVBRA': 0.0001338479600371356,
#  'CLSNVBSU': 0.0001338479600371356,
#  'CLSNVBCL': 0.0001338479600371356,
#  'CLSNVBSN': 0.0001338479600371356,
#  'CLSNVBFO': 0.0001338479600371356,
#  'CLSNDRRA': 8.438240958862896e-05,
#  'CLSNDRSU': 8.438240958862896e-05,
#  'CLSNDRCL': 8.438240958862896e-05,
#  'CLSNDRSN': 8.438240958862896e-05,
#  'CLSNDRFO': 8.438240958862896e-05,
#  'CLSNSVRA': 6.983371828024464e-05,
#  'CLSNSVSU': 6.983371828024464e-05,
#  'CLSNSVCL': 6.983371828024464e-05,
#  'CLSNSVSN': 6.983371828024464e-05,
#  'CLSNSVFO': 6.983371828024464e-05,
#  'CLSNPGRA': 6.69239800185678e-05,
#  'CLSNPGSU': 6.69239800185678e-05,
#  'CLSNPGCL': 6.69239800185678e-05,
#  'CLSNPGSN': 6.69239800185678e-05,
#  'CLSNPGFO': 6.69239800185678e-05,
#  'CLSNKMRA': 6.401424175689093e-05,
#  'CLSNKMSU': 6.401424175689093e-05,
#  'CLSNKMCL': 6.401424175689093e-05,
#  'CLSNKMSN': 6.401424175689093e-05,
#  'CLSNKMFO': 6.401424175689093e-05,
#  'CLSNLSRA': 3.7826597401799186e-05,
#  'CLSNLSSU': 3.7826597401799186e-05,
#  'CLSNLSCL': 3.7826597401799186e-05,
#  'CLSNLSSN': 3.7826597401799186e-05,
#  'CLSNLSFO': 3.7826597401799186e-05,
#  'CLSNMSRA': 3.491685914012232e-05,
#  'CLSNMSSU': 3.491685914012232e-05,
#  'CLSNMSCL': 3.491685914012232e-05,
#  'CLSNMSSN': 3.491685914012232e-05,
#  'CLSNMSFO': 3.491685914012232e-05,
#  'CLSNYTRA': 3.2007120878445464e-05,
#  'CLSNYTSU': 3.2007120878445464e-05,
#  'CLSNYTCL': 3.2007120878445464e-05,
#  'CLSNYTSN': 3.2007120878445464e-05,
#  'CLSNYTFO': 3.2007120878445464e-05,
#  'CLSNZGRA': 1.745842957006116e-05,
#  'CLSNZGSU': 1.745842957006116e-05,
#  'CLSNZGCL': 1.745842957006116e-05,
#  'CLSNZGSN': 1.745842957006116e-05,
#  'CLSNZGFO': 1.745842957006116e-05,
#  'CLSNAARA': 1.1638953046707443e-05,
#  'CLSNAASU': 1.1638953046707443e-05,
#  'CLSNAACL': 1.1638953046707443e-05,
#  'CLSNAASN': 1.1638953046707443e-05,
#  'CLSNAAFO': 1.1638953046707443e-05,
#  'CLSNNVRA': 5.819476523353721e-06,
#  'CLSNNVSU': 5.819476523353721e-06,
#  'CLSNNVCL': 5.819476523353721e-06,
#  'CLSNNVSN': 5.819476523353721e-06,
#  'CLSNNVFO': 5.819476523353721e-06,
#  'CLSNNLRA': 0.0,
#  'CLSNNLSU': 0.0,
#  'CLSNNLCL': 0.0,
#  'CLSNNLSN': 0.0,
#  'CLSNNLFO': 0.0,
#  'CLSNNHRA': 0.0,
#  'CLSNNHSU': 0.0,
#  'CLSNNHCL': 0.0,
#  'CLSNNHSN': 0.0,
#  'CLSNNHFO': 0.0,
#  'CLFOMVRA': 0.0009922207472318095,
#  'CLFOMVSU': 0.0009922207472318095,
#  'CLFOMVCL': 0.0009922207472318095,
#  'CLFOMVSN': 0.0009922207472318095,
#  'CLFOMVFO': 0.0009922207472318095,
#  'CLFOCLRA': 0.000689607968017416,
#  'CLFOCLSU': 0.000689607968017416,
#  'CLFOCLCL': 0.000689607968017416,
#  'CLFOCLSN': 0.000689607968017416,
#  'CLFOCLFO': 0.000689607968017416,
#  ...}

# %% [markdown]
# Sample Space when Redbull wins at least one match during rains

# %%
def RedBullWinsOnRainyDay(outcome): return outcome[:4] == 'MVRA' or outcome[:4] == 'SPRA' or outcome[4:] == 'MVRA' or outcome[4:] == 'SPRA'
def RedBullWinsBothRaces(outcome): return (outcome[:2] == 'MV' or outcome[:2] == 'SP') and (outcome[4:6] == 'MV' or outcome[4:6] == 'SP')

# there is repetion of cases with outcome 'MVRASPRA', 'MVRAMVRA', 'SPRASPRA' and 'SPRAMVRA'
repeated = such_that(RedBullWinsOnRainyDay, NGPIGPW)
diff = repeated['MVRASPRA'] + repeated['MVRAMVRA'] + repeated['SPRASPRA'] + repeated['SPRAMVRA']
# print(repeated)

# remove the diff cases probability
RedBullWinsGivenRainyCondition = p(RedBullWinsBothRaces, such_that(RedBullWinsOnRainyDay, NGPIGPW)) - diff
RedBullWinsGivenRainyCondition
# Out:
# 0.27166780725013684

# %% [markdown]
# ANSWER 4 :
#
#     Lets create a set of all the 100 events and a set of number of drivers that could be present in an event(0 to 100)

# %%
Events = {'E' + str(i) for i in range(1,101)} #1-100 
Drivers = {'D' + str(i) for i in range(101)} #0,100 E1D1 E1D3 E1D2
#this event covers no drivers and multiple drivers

# %% [markdown]
# Now, the sample space for each event having each number of driver will be :

# %%
TotalCases = {a + b for a in Events for b in Drivers}
print(TotalCases) # 'E46D22', 'E12D90', 'E85D24', 'E49D4', 'E18D65'
len(TotalCases)
# Out:
# {'E4D3', 'E3D2', 'E3D0', 'E3D4', 'E4D1', 'E4D4', 'E2D3', 'E1D1', 'E3D1', 'E1D3', 'E1D0', 'E2D4', 'E1D4', 'E2D0', 'E2D2', 'E1D2', 'E4D2', 'E2D1', 'E4D0', 'E3D3'}
# 20

# %% [markdown]
#     Probability of finding my favourite driver in the event that I attended :

# %%
def FavDriverProbability(Event): return p( lambda x:x.startswith('E' + Event) and x.endswith('D1'), TotalCases)

# %%
ProbabilityOfFindingFavoriteDriver = FavDriverProbability('41')
ProbabilityOfFindingFavoriteDriver
# Out:
# Fraction(1, 10100)

# %% [markdown]
# Probability of finding a Formula driver : 1 - Probability of finding no driver at the event

# %%
def NoDriver(outcome) : return outcome.endswith('D0')

# %%
NoDriverProbability = p(NoDriver, TotalCases)

# %%
OneDriverProbability = 1 - NoDriverProbability
OneDriverProbability
# Out:
# Fraction(100, 101)

# %% [markdown]
# As we saw in the above calculation that probability of finding a F1 driver is very high (99%) in one event, so the number of shows one has to attend in order to get 50% chance of meeting a F1 driver is 1.
